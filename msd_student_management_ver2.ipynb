# %%
import tkinter as tk
from tkinter import ttk as ttk
from tkinter import scrolledtext as scr
from openpyxl import Workbook

def view_all_student():   
    pass

def add_student():
    pass

def update_student():
    pass

def delete_student():
    pass

def delete_all_student():
    pass

def exit():
    window.destroy()

# Khởi tạo window chính
window = tk.Tk()
window.title('MSD STUDENT MANAGEMENT')
window.geometry('530x600')
window.resizable(False,False)

# Khởi tạo đối tượng đọc file excel
wb = Workbook()
ws = wb.active

# Khởi tạo biến variable của các widget
display_tittle_value = tk.StringVar()
display_tittle_value.set('')
info_column = ('STT','First Name','Last Name','Phone.No','Class')

# ===========================================
# Khởi tạo các trường để nhập thông tin
frame_input_info = ttk.Frame(window)

label_frame_info = ttk.Label(frame_input_info,text='Input information')
label_frame_info.grid(row=0,column=0,sticky='w',padx='5',pady='5')

label_fname = ttk.Label(frame_input_info,text='First Name')
label_fname.grid(row=1,column=0,sticky='w',padx='5',pady='5')

label_lname = ttk.Label(frame_input_info,text='Last Name')
label_lname.grid(row=1,column=3,sticky='w',padx='5',pady='5')

label_phone = ttk.Label(frame_input_info,text='Phone.No')
label_phone.grid(row=2,column=0,sticky='w',padx='5',pady='5')

label_class = ttk.Label(frame_input_info,text='Class')
label_class.grid(row=3,column=0,sticky='w',padx='5',pady='5')

entry_fname = ttk.Entry(frame_input_info)
entry_fname.grid(row=1,column=1,sticky='w',pady='5')

entry_lname = ttk.Entry(frame_input_info)
entry_lname.grid(row=1,column=4,sticky='w',pady='5')

entry_phone = ttk.Entry(frame_input_info)
entry_phone.grid(row=2,column=1,sticky='w',pady='5')

cbx_class = ttk.Combobox(frame_input_info,state= "readonly")
cbx_class['value']=('--Select a class--','Mất gốc','Toeic','Luyện đề')
cbx_class.current(0)
cbx_class.grid(row=3,column=1,sticky='w',pady='5')

# ===========================================
# Khởi tạo các Button để thực hiện các chức năng
frame_function = ttk.Frame(window)

label_frame_function = ttk.Label(frame_function,text='Function')
label_frame_function.grid(row=0,column=0,sticky='w',padx='5',pady='5')

btn_view = ttk.Button(frame_function, text='View All', command=lambda:view_all_student())
btn_view.grid(row=1,column=0,sticky='w',padx='5',pady='5')

btn_add = ttk.Button(frame_function, text='Add', command=lambda:add_student())
btn_add.grid(row=1,column=1,sticky='w',padx='5',pady='5')

btn_update = ttk.Button(frame_function, text='Update', command=update_student)
btn_update.grid(row=1,column=2,sticky='w',padx='5',pady='5')

btn_delete = ttk.Button(frame_function, text='Delete', command=delete_student)
btn_delete.grid(row=1,column=3,sticky='w',padx='5',pady='5')

btn_delete_all_btn = ttk.Button(frame_function, text='Delete All', command=delete_all_student)
btn_delete_all_btn.grid(row=1,column=4,sticky='w',padx='5',pady='5')

btn_exit = ttk.Button(frame_function, text='Exit', command=exit)
btn_exit.grid(row=1,column=5,sticky='w',padx='5',pady='5')


# ===========================================
# Khởi tạo các trường để search
frame_search = ttk.Frame(window)

entry_search = ttk.Entry(frame_search)
entry_search.grid(row=0,column=0,sticky='e',padx='5',pady='5')

btn_search = ttk.Button(frame_search,text='Search')
btn_search.grid(row=0,column=1,sticky='e',padx='5',pady='5')


# ===========================================
# Khởi tạo các trường để hiển thị thông tin
frame_display_info = ttk.Frame(window)

tvw_info = ttk.Treeview(frame_display_info,column=info_column,show='headings')
tvw_info.grid(row=1,column=0,sticky='w',padx='5',pady='5')

# ===========================================
# Sắp xếp các frame
frame_input_info.pack(padx='10',pady='20',anchor='w')
frame_function.pack(padx='10',pady='20',anchor='w')
frame_search.pack(padx='10',pady='0',anchor='e')
frame_display_info.pack(padx='10',pady='0',expand=True,fill='y',anchor='w')

window.mainloop()
