# %%
import tkinter as tk
from tkinter import ttk as ttk
from tkinter import scrolledtext as scr

def view_all_student():
    global display_tittle_value
    display_tittle_value.set('All student\'s infomation')
    frame_display_info.grid_forget()
    display_info.pack()
    frame_display_info.grid(row=1,column=0,sticky='w',padx='5',pady='5')
    frame_display_info.tkraise()
#     frame_display_info.grid(row=1,column=0,sticky='w',padx='5',pady='5')
    

def add_student():
    global display_tittle_value
    display_tittle_value.set('Add new student')
    if frame_display_info.winfo_manager():
        frame_display_info.grid_forget()
    else:
        frame_add.pack()
        frame_display_info.grid(row=1,column=0,sticky='w',padx='5',pady='5')
        frame_display_info.tkraise()
    


def update_student():
    pass

def delete_student():
    pass

def delete_all_student():
    pass

def exit():
    window.destroy()

window = tk.Tk()
window.title('MSD STUDENT MANAGEMENT')
window.geometry('800x500')
window.resizable(False,False)

# Khởi tạo biến variable của các widget
display_tittle_value = tk.StringVar()
display_tittle_value.set('')

# Khởi tạo các Button để thực hiện các chức năng
frame_function = ttk.Frame(window)
funtion_tittle = ttk.Label(frame_function,text='Function')
funtion_tittle.grid(row=0,column=0,sticky='w',padx='5',pady='5')
view_btn = ttk.Button(frame_function, text='View All', command=lambda:view_all_student())
view_btn.grid(row=1,column=0,sticky='w',padx='5',pady='5')
add_btn = ttk.Button(frame_function, text='Add', command=lambda:add_student())
add_btn.grid(row=2,column=0,sticky='w',padx='5',pady='5')
update_btn = ttk.Button(frame_function, text='Update', command=update_student)
update_btn.grid(row=3,column=0,sticky='w',padx='5',pady='5')
delete_btn = ttk.Button(frame_function, text='Delete', command=delete_student)
delete_btn.grid(row=4,column=0,sticky='w',padx='5',pady='5')
delete_all_btn = ttk.Button(frame_function, text='Delete All', command=delete_all_student)
delete_all_btn.grid(row=5,column=0,sticky='w',padx='5',pady='5')
exit_btn = ttk.Button(frame_function, text='Exit', command=exit)
exit_btn.grid(row=6,column=0,sticky='w',padx='5',pady='5')

# =====================================================
# Khởi tạo tiêu đề hiển thị thông tin
frame_display = ttk.Frame(window)
display_tittle = ttk.Label(frame_display,textvariable=display_tittle_value)
display_tittle.grid(row=0,column=0,sticky='w',padx='5',pady='5')

# Khởi tạo nội dung hiển thị thông tin
frame_display_info = ttk.Frame(frame_display)
display_info = scr.ScrolledText(frame_display_info,width='200',heigh='400')

# Khởi tạo phần hiển thị chức năng add
frame_add = ttk.Frame(frame_display_info)
name_label = ttk.Label(frame_add,text='Name')
name_label.grid(row=0,column=0,sticky='w',padx='5',pady='5')
name_entry = ttk.Entry(frame_add)
name_entry.grid(row=0,column=1,sticky='w',padx='5',pady='5')


frame_display_info.grid(row=1,column=0,sticky='w',padx='5',pady='5')


frame_function.pack(side='left',padx='10',pady='20',anchor='n')
frame_display.pack(side='left',padx='10',pady='20',anchor='n')


window.mainloop()
